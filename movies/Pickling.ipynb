# %%
data_dict = {'Irmak': 12, 'Laurie' : 1}

# !ls
# Out:
# Pickling.ipynb  README.md       bomojo.py       bomojo.pyc      gettitlelist.py scraper.py      scraper.pyc

# %%
import pickle

with open('my_data.pkl', 'w') as picklefile:
    pickle.dump(data_dict, picklefile)

# %%
# !ls
# Out:
# Pickling.ipynb  README.md       bomojo.py       bomojo.pyc      gettitlelist.py my_data.pkl     scraper.py      scraper.pyc

# %%
import pickle

with open('my_data.pkl','r') as picklefile:
    my_old_data = pickle.load(picklefile)

# %%
print my_old_data
# Out:
# {'Laurie': 1, 'Irmak': 12}

# %%
with open('movie_data_dict.pkl','r') as picklefile1:
    old_movie_data = pickle.load(picklefile1)

# %%
print len(old_movie_data)
for movie in old_movie_data:
    print movie.values()
# Out:
# 500
# [u'PG-13', u'James Cameron', u'Avatar', 749766139, 160, datetime.datetime(2009, 12, 18, 0, 0)]
# [u'PG-13', u'James Cameron', u'Titanic', 600788188, 194, datetime.datetime(1997, 12, 19, 0, 0)]
# [u'PG-13', u'Joss Whedon', u"Marvel's The Avengers", 623357910, 142, datetime.datetime(2012, 5, 4, 0, 0)]
# [u'PG-13', u'Christopher Nolan', u'The Dark Knight', 533345358, 150, datetime.datetime(2008, 7, 18, 0, 0)]
# [u'PG', u'George Lucas', u'Star Wars: Episode I - The Phantom Menace', 431088295, 133, datetime.datetime(1999, 5, 19, 0, 0)]
# [u'PG', u'George Lucas', u'Star Wars', 307263857, 121, datetime.datetime(1977, 5, 25, 0, 0)]
# [u'PG-13', u'Christopher Nolan', u'The Dark Knight Rises', 448139099, 165, datetime.datetime(2012, 7, 20, 0, 0)]
# [u'PG', u'Andrew AdamsonKelly AsburyConrad Vernon', u'Shrek 2', 441226247, 93, datetime.datetime(2004, 5, 19, 0, 0)]
# [u'PG', u'Steven Spielberg', u'E.T.: The Extra-Terrestrial', 359197037, 117, datetime.datetime(1982, 6, 11, 0, 0)]
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
movies_recent_data = pd.DataFrame(old_movie_data)

# %%
movies_recent_data.head(500)
# Out:
#                                     director  domestic_total_gross  \
# 0                              James Cameron             749766139
# 1                              James Cameron             600788188
# 2                                Joss Whedon             623357910
# 3                          Christopher Nolan             533345358
# 4                               George Lucas             431088295
# 5                               George Lucas             307263857
# 6                          Christopher Nolan             448139099
# 7    Andrew AdamsonKelly AsburyConrad Vernon             441226247
# 8                           Steven Spielberg             359197037
# 9                           Francis Lawrence             424668047
# 10                            Gore Verbinski             423315812
# 11                   Roger AllersRob Minkoff             312855561
# 12                               Lee Unkrich             415004880
# ...
