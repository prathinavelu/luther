# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from datetime import datetime

# Note: Here I'm loading my movie csv file to make a data frame
# You can work on your own data frame

movies = pd.read_csv('2013_movies.csv', parse_dates={'Date':['ReleaseDate']})

movies.head()
# Out:
#         Date                            Title     Budget  DomesticTotalGross  \
# 0 2013-11-22  The Hunger Games: Catching Fire  130000000           424668047
# 1 2013-05-03                       Iron Man 3  200000000           409013994
# 2 2013-11-22                           Frozen  150000000           400738009
# 3 2013-07-03                  Despicable Me 2   76000000           368061265
# 4 2013-06-14                     Man of Steel  225000000           291045518
#
#                     Director Rating  Runtime
# 0           Francis Lawrence  PG-13      146
# 1                Shane Black  PG-13      129
# 2     Chris BuckJennifer Lee     PG      108
# 3  Pierre CoffinChris Renaud     PG       98
# 4                Zack Snyder  PG-13      143

# %% [markdown]
# ### Predict Gross using Budget only

# %%
movies_with_budget = movies[ -np.isnan(movies.Budget) ]
movies_with_budget.tail()
# Out:
#          Date            Title    Budget  DomesticTotalGross  \
# 95 2013-09-20             Rush  38000000            26947624
# 96 2013-03-29         The Host  40000000            26627201
# 97 2013-08-23  The World's End  20000000            26004851
# 98 2013-03-01      21 and Over  13000000            25682380
# 99 2013-12-18              Her  23000000            25568251
#
#                 Director Rating  Runtime
# 95            Ron Howard      R      123
# 96         Andrew Niccol  PG-13      125
# 97          Edgar Wright      R      109
# 98  Jon LucasScott Moore      R       93
# 99           Spike Jonze      R      120

# %%
movies_with_budget['Ones'] = 1.0
movies_with_budget.tail()
# Out:
#          Date            Title    Budget  DomesticTotalGross  \
# 95 2013-09-20             Rush  38000000            26947624
# 96 2013-03-29         The Host  40000000            26627201
# 97 2013-08-23  The World's End  20000000            26004851
# 98 2013-03-01      21 and Over  13000000            25682380
# 99 2013-12-18              Her  23000000            25568251
#
#                 Director Rating  Runtime  Ones
# 95            Ron Howard      R      123     1
# 96         Andrew Niccol  PG-13      125     1
# 97          Edgar Wright      R      109     1
# 98  Jon LucasScott Moore      R       93     1
# 99           Spike Jonze      R      120     1

# %%
import statsmodels.formula.api as sm

X = movies_with_budget[['Budget', 'Ones']]
Y = movies_with_budget['DomesticTotalGross']
linmodel = sm.OLS(Y,X).fit()
linmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     DomesticTotalGross   R-squared:                       0.286
# Model:                            OLS   Adj. R-squared:                  0.278
# Method:                 Least Squares   F-statistic:                     34.82
# Date:                Wed, 10 Sep 2014   Prob (F-statistic):           6.80e-08
# Time:                        09:41:32   Log-Likelihood:                -1738.1
# No. Observations:                  89   AIC:                             3480.
# Df Residuals:                      87   BIC:                             3485.
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Budget         0.7846      0.133      5.901      0.000         0.520     1.049
# Ones         4.44e+07   1.27e+07      3.504      0.001      1.92e+07  6.96e+07
# ==============================================================================
# Omnibus:                       39.749   Durbin-Watson:                   0.674
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               99.441
# Skew:                           1.587   Prob(JB):                     2.55e-22
# Kurtosis:                       7.091   Cond. No.                     1.54e+08
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.54e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### Plot the model

# %%
import matplotlib.pyplot as plt
plt.scatter(movies_with_budget.Budget, movies_with_budget.DomesticTotalGross)
plt.xlabel('Budget')
plt.ylabel('Box Office')
plt.plot(movies_with_budget.Budget, linmodel.predict(X), 'r')

from statsmodels.sandbox.regression.predstd import wls_prediction_std
prstd, conf_lower, conf_upper = wls_prediction_std(linmodel)
plt.plot(movies_with_budget['Budget'], conf_lower, 'y--')
plt.plot(movies_with_budget['Budget'], conf_upper, 'y--')

# %% [markdown]
# #### Plot the predictions of the model against true values

# %%
# plot the predictions 
plt.plot(movies_with_budget['DomesticTotalGross'],linmodel.predict(X),'go')
# plot the 1:1 actual gross line
plt.plot(movies_with_budget['DomesticTotalGross'], movies_with_budget['DomesticTotalGross'], 'b--')
# axis labels
plt.xlabel('Actual Gross')
plt.ylabel('Predicted Gross by Rating Model')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-bc8feeb0d624> in <module>()
#       1 # plot the predictions
# ----> 2 plt.plot(movies_with_budget['DomesticTotalGross'],linmodel.predict(X),'go')
#       3 # plot the 1:1 actual gross line
#       4 plt.plot(movies_with_budget['DomesticTotalGross'], movies_with_budget['DomesticTotalGross'], 'b--')
#       5 # axis labels
#
# /usr/local/lib/python2.7/site-packages/statsmodels/base/model.pyc in predict(self, exog, transform, *args, **kwargs)
#     878             exog = dmatrix(self.model.data.orig_exog.design_info.builder,
#     879                     exog)
# --> 880         return self.model.predict(self.params, exog, *args, **kwargs)
#     881
#     882
#
# /usr/local/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in predict(self, params, exog)
#     175         if exog is None:
#     176             exog = self.exog
# --> 177         return np.dot(exog, params)
#     178
#     179 class GLS(RegressionModel):
#
# ValueError: matrices are not aligned

# %% [markdown]
# ### Same regression with scikit.learn

# %%
# Same model with scikitlearn

from sklearn.linear_model import LinearRegression

np_movies = np.matrix(movies_with_budget)

X = np_movies[:, 2]  # budget
Y = np_movies[:, 3]  # gross

sk_linmodel = LinearRegression()
sk_linmodel.fit(X,Y)

x, y = X.A1, Y.A1

print 'coefficient:\t %g'% sk_linmodel.coef_[0,0]
print 'intercept:\t %g'  % sk_linmodel.intercept_[0]
print 'R^2:      \t %g'  % sk_linmodel.score(X, Y)

plt.scatter(x, y)
plt.xlabel("Budget")
plt.ylabel("Box Office")
plt.plot(x, sk_linmodel.predict(X), 'r')
# Out:
# coefficient:	 0.784637
# intercept:	 4.43956e+07
# R^2:      	 0.285814

# %% [markdown]
# ### Predict Gross using Ratings (categorical variable)

# %%
m = movies_with_budget
pd.get_dummies(m['Rating'])
# Out:
#     PG  PG-13  R
# 0    0      1  0
# 1    0      1  0
# 2    1      0  0
# 3    1      0  0
# 4    0      1  0
# 5    0      1  0
# 8    0      1  0
# 9    1      0  0
# 10   0      1  0
# 11   0      1  0
# 12   0      1  0
# 13   1      0  0
# 14   0      0  1
# 15   0      0  1
# 16   0      0  1
# 17   0      1  0
# 18   0      0  1
# 19   0      0  1
# 20   0      1  0
# 21   0      1  0
# 22   0      1  0
# 23   0      0  1
# 24   0      1  0
# 25   1      0  0
# 26   0      1  0
# 27   0      0  1
# 28   0      1  0
# 29   0      0  1
# 30   1      0  0
# 31   0      1  0
# ..  ..    ... ..
# 61   0      0  1
# 62   1      0  0
# 63   0      0  1
# 64   0      0  1
# 65   0      1  0
# 68   0      0  1
# 69   0      0  1
# 70   0      0  1
# 71   0      1  0
# 72   0      1  0
# 75   0      0  1
# 76   0      0  1
# 77   0      1  0
# 79   0      1  0
# 80   0      0  1
# 81   1      0  0
# 82   0      0  1
# 84   0      1  0
# 88   0      1  0
# 89   0      1  0
# 90   0      1  0
# 91   0      1  0
# 92   1      0  0
# 93   0      0  1
# 94   0      0  1
# 95   0      0  1
# 96   0      1  0
# 97   0      0  1
# 98   0      0  1
# 99   0      0  1
#
# [89 rows x 3 columns]

# %%
m = pd.concat([m,pd.get_dummies(m['Rating'])], axis=1)
m.head()
# Out:
#         Date                            Title     Budget  DomesticTotalGross  \
# 0 2013-11-22  The Hunger Games: Catching Fire  130000000           424668047
# 1 2013-05-03                       Iron Man 3  200000000           409013994
# 2 2013-11-22                           Frozen  150000000           400738009
# 3 2013-07-03                  Despicable Me 2   76000000           368061265
# 4 2013-06-14                     Man of Steel  225000000           291045518
#
#                     Director Rating  Runtime  Ones  PG  PG-13  R
# 0           Francis Lawrence  PG-13      146     1   0      1  0
# 1                Shane Black  PG-13      129     1   0      1  0
# 2     Chris BuckJennifer Lee     PG      108     1   1      0  0
# 3  Pierre CoffinChris Renaud     PG       98     1   1      0  0
# 4                Zack Snyder  PG-13      143     1   0      1  0

# %%
X = m[['PG', 'PG-13', 'R', 'Ones']]
Y = m['DomesticTotalGross']
rating_linmodel = sm.OLS(Y, X).fit()
rating_linmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     DomesticTotalGross   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     3.180
# Date:                Wed, 10 Sep 2014   Prob (F-statistic):             0.0465
# Time:                        10:07:38   Log-Likelihood:                -1749.9
# No. Observations:                  89   AIC:                             3506.
# Df Residuals:                      86   BIC:                             3513.
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# PG           5.08e+07   1.72e+07      2.951      0.004      1.66e+07   8.5e+07
# PG-13       3.563e+07    1.2e+07      2.976      0.004      1.18e+07  5.94e+07
# R          -6.104e+06   1.28e+07     -0.476      0.636     -3.16e+07  1.94e+07
# Ones        8.033e+07   7.41e+06     10.836      0.000      6.56e+07  9.51e+07
# ==============================================================================
# Omnibus:                       41.953   Durbin-Watson:                   0.160
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               91.921
# Skew:                           1.796   Prob(JB):                     1.10e-20
# Kurtosis:                       6.447   Cond. No.                     1.49e+08
# ==============================================================================
#
# Warnings:
# [1] The smallest eigenvalue is 5.59e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# #### Plot the predictions

# %%
# plot the predictions 
plt.plot(m['DomesticTotalGross'], rating_linmodel.predict(X), 'go')
# plot the 1:1 actual gross line
plt.plot(m['DomesticTotalGross'], m['DomesticTotalGross'], 'b--')
# axis labels
plt.xlabel('Actual Gross')
plt.ylabel('Predicted Gross by Rating Model')
